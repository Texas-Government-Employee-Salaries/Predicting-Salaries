# %%
import pandas as pd
import matplotlib.pyplot as plt

import seaborn as sns

# custom module imports
# import acquire as aq
import Prepare as pr
# import explore as ex

# feature selection imports
from sklearn.feature_selection import SelectKBest, f_regression
from sklearn.feature_selection import RFE

# import scaling methods
from sklearn.preprocessing import RobustScaler, StandardScaler
from scipy import stats
from sklearn.model_selection import train_test_split

# import modeling methods
from sklearn.cluster import KMeans
from sklearn.metrics import mean_squared_error
from sklearn.linear_model import LinearRegression, LassoLars, TweedieRegressor
from sklearn.preprocessing import PolynomialFeatures
from sklearn.metrics import explained_variance_score
from scipy import stats

# import to remove warnings
import warnings
warnings.filterwarnings("ignore")

# %%
df = pd.read_csv('salaries.csv')

# %%
df.head()
# Out:
#    AGY                                               NAME  \
# 0  101  SENATE                                        ...
# 1  104  LEGISLATIVE BUDGET BOARD                      ...
# 2  101  SENATE                                        ...
# 3  104  LEGISLATIVE BUDGET BOARD                      ...
# 4  101  SENATE                                        ...
#
#                          LASTNAME                       FIRSTNAME MI  \
# 0  GILLIAM                         STACEY                          L
# 1  GILLIAM                         STACEY                          L
# 2  NELSON                          DAVID
# 3  NELSON                          DAVID
# 4  ROCHA                           MARIE                           S
#
#    JOBCLASS                                           JC TITLE  \
# 0  7101      LEG. OFFICIAL/ADMINISTRATOR                   ...
# 1  C160      COMMITTEE DIRECTOR                            ...
# 2  7101      LEG. OFFICIAL/ADMINISTRATOR                   ...
# 3  P080      SENIOR BUDGET ADVISOR                         ...
# 4  7103      LEG. SERVICE/MAINTENANCE                      ...
#
#               RACE              SEX                                   EMPTYPE  \
# 0  WHITE            FEMALE           URP - UNCLASSIFIED REGULAR PART-TIME
# 1  WHITE            FEMALE           URP - UNCLASSIFIED REGULAR PART-TIME
# 2  WHITE            MALE             URP - UNCLASSIFIED REGULAR PART-TIME
# 3  WHITE            MALE             URP - UNCLASSIFIED REGULAR PART-TIME
# 4  HISPANIC         FEMALE           URF - UNCLASSIFIED REGULAR FULL-TIME
#
#    ... RATE  HRSWKD  MONTHLY    ANNUAL  STATENUM  duplicated  \
# 0  ...  0.0    20.0   8100.0   97200.0    339371        True
# 1  ...  0.0    20.0   7000.0   84000.0    339371        True
# 2  ...  0.0    20.0   9500.0  114000.0    193187        True
# 3  ...  0.0    20.0   8000.0   96000.0    193187        True
# 4  ...  0.0    41.0   3365.4   40384.8    152257        True
#
#   multiple_full_time_jobs combined_multiple_jobs summed_annual_salary  \
# 0                     NaN                    NaN             181200.0
# 1                     NaN                    NaN                  NaN
# 2                     NaN                    NaN             210000.0
# 3                     NaN                    NaN                  NaN
# 4                     NaN                   True                  NaN
#
#    hide_from_search
# 0               NaN
# 1              True
# 2               NaN
# 3              True
# 4               NaN
#
# [5 rows x 21 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 144738 entries, 0 to 144737
# Data columns (total 21 columns):
#  #   Column                   Non-Null Count   Dtype
# ---  ------                   --------------   -----
#  0   AGY                      144738 non-null  int64
#  1   NAME                     144738 non-null  object
#  2   LASTNAME                 144738 non-null  object
#  3   FIRSTNAME                144738 non-null  object
#  4   MI                       144738 non-null  object
#  5   JOBCLASS                 144738 non-null  object
#  6   JC TITLE                 144738 non-null  object
#  7   RACE                     144738 non-null  object
#  8   SEX                      144738 non-null  object
#  9   EMPTYPE                  144738 non-null  object
#  10  HIREDT                   144738 non-null  object
#  11  RATE                     144738 non-null  float64
#  12  HRSWKD                   144738 non-null  float64
#  13  MONTHLY                  144738 non-null  float64
#  14  ANNUAL                   144738 non-null  float64
#  15  STATENUM                 144738 non-null  int64
#  16  duplicated               76 non-null      object
#  17  multiple_full_time_jobs  18 non-null      object
#  18  combined_multiple_jobs   37 non-null      object
#  19  summed_annual_salary     11 non-null      float64
#  20  hide_from_search         11 non-null      object
# dtypes: float64(5), int64(2), object(14)
# memory usage: 23.2+ MB

# %%
df[df.AGY==696]
# Out:
#         AGY                                               NAME  \
# 13      696  TEXAS DEPARTMENT OF CRIMINAL JUSTICE          ...
# 18      696  TEXAS DEPARTMENT OF CRIMINAL JUSTICE          ...
# 103113  696  TEXAS DEPARTMENT OF CRIMINAL JUSTICE          ...
# 103114  696  TEXAS DEPARTMENT OF CRIMINAL JUSTICE          ...
# 103115  696  TEXAS DEPARTMENT OF CRIMINAL JUSTICE          ...
# ...     ...                                                ...
# 136067  696  TEXAS DEPARTMENT OF CRIMINAL JUSTICE          ...
# 136068  696  TEXAS DEPARTMENT OF CRIMINAL JUSTICE          ...
# 136069  696  TEXAS DEPARTMENT OF CRIMINAL JUSTICE          ...
# 136070  696  TEXAS DEPARTMENT OF CRIMINAL JUSTICE          ...
# 136071  696  TEXAS DEPARTMENT OF CRIMINAL JUSTICE          ...
#
#                               LASTNAME                       FIRSTNAME MI  \
# 13      AKOZAR                          ANGEL                           A
# 18      HARRIS                          DAJIA                           D
# 103113  AARON                           AMANDA                          R
# 103114  AARON                           GRACE
# 103115  AARON                           LA VONDA                        P
# ...                                ...                             ... ..
# 136067  ZWAHR                           DEAN                            A
# 136068  ZWAR                            JEREMY                          W
# 136069  ZWEIACKER                       KARA                            D
# 136070  ZWEIACKER                       MARCUS                          D
# 136071  ZWILLENBERG                     GORDON                          D
#
#         JOBCLASS                                           JC TITLE  \
# 13      4503      CORREC OFFCR III                              ...
# 18      4503      CORREC OFFCR III                              ...
# 103113  1351      INVESTIGATOR II                               ...
# 103114  4504      CORREC  OFFICER IV                            ...
# 103115  0057      CLERK II                                      ...
# ...          ...                                                ...
# 136067  4505      CORREC  OFFICER V                             ...
# 136068  4510      SGT OF CORREC OFFCRS                          ...
# 136069  4503      CORREC OFFCR III                              ...
# 136070  4504      CORREC  OFFICER IV                            ...
# 136071  4505      CORREC  OFFICER V                             ...
#
#                    RACE              SEX  \
# 13      BLACK            FEMALE
# 18      BLACK            FEMALE
# 103113  WHITE            FEMALE
# 103114  BLACK            FEMALE
# 103115  BLACK            FEMALE
# ...                 ...              ...
# 136067  WHITE            MALE
# 136068  WHITE            MALE
# 136069  WHITE            FEMALE
# 136070  WHITE            MALE
# 136071  WHITE            MALE
#
#                                          EMPTYPE  ... RATE  HRSWKD  MONTHLY  \
# 13      CRF - CLASSIFIED REGULAR FULL-TIME        ...  0.0    40.0  3019.84
# 18      CRF - CLASSIFIED REGULAR FULL-TIME        ...  0.0    40.0  3019.84
# 103113  CRF - CLASSIFIED REGULAR FULL-TIME        ...  0.0    40.0  2920.42
# 103114  CRF - CLASSIFIED REGULAR FULL-TIME        ...  0.0    40.0  3284.27
# 103115  CRF - CLASSIFIED REGULAR FULL-TIME        ...  0.0    40.0  2031.29
# ...                                          ...  ...  ...     ...      ...
# 136067  CRF - CLASSIFIED REGULAR FULL-TIME        ...  0.0    40.0  3629.45
# 136068  CRF - CLASSIFIED REGULAR FULL-TIME        ...  0.0    40.0  3906.09
# 136069  CRF - CLASSIFIED REGULAR FULL-TIME        ...  0.0    40.0  3019.84
# 136070  CRF - CLASSIFIED REGULAR FULL-TIME        ...  0.0    40.0  3284.27
# 136071  CRF - CLASSIFIED REGULAR FULL-TIME        ...  0.0    40.0  3720.17
#
#           ANNUAL  STATENUM  duplicated multiple_full_time_jobs  \
# 13      36238.08    957115        True                    True
# 18      36238.08   1272776        True                    True
# 103113  35045.04    382675         NaN                     NaN
# 103114  39411.24   1183223         NaN                     NaN
# 103115  24375.48    106962         NaN                     NaN
# ...          ...       ...         ...                     ...
# 136067  43553.40      8523         NaN                     NaN
# 136068  46873.08     15034         NaN                     NaN
# 136069  36238.08   1287136         NaN                     NaN
# 136070  39411.24   1143776         NaN                     NaN
# 136071  44642.04    125047         NaN                     NaN
#
#        combined_multiple_jobs summed_annual_salary  hide_from_search
# 13                        NaN                  NaN               NaN
# 18                        NaN                  NaN               NaN
# 103113                    NaN                  NaN               NaN
# 103114                    NaN                  NaN               NaN
# 103115                    NaN                  NaN               NaN
# ...                       ...                  ...               ...
# 136067                    NaN                  NaN               NaN
# 136068                    NaN                  NaN               NaN
# 136069                    NaN                  NaN               NaN
# 136070                    NaN                  NaN               NaN
# 136071                    NaN                  NaN               NaN
#
# [32961 rows x 21 columns]

# %%
df[df.AGY==529]
# Out:
#        AGY                                               NAME  \
# 10     529  HEALTH AND HUMAN SERVICES COMMISSION          ...
# 15     529  HEALTH AND HUMAN SERVICES COMMISSION          ...
# 16     529  HEALTH AND HUMAN SERVICES COMMISSION          ...
# 17     529  HEALTH AND HUMAN SERVICES COMMISSION          ...
# 20     529  HEALTH AND HUMAN SERVICES COMMISSION          ...
# ...    ...                                                ...
# 68693  529  HEALTH AND HUMAN SERVICES COMMISSION          ...
# 68694  529  HEALTH AND HUMAN SERVICES COMMISSION          ...
# 68695  529  HEALTH AND HUMAN SERVICES COMMISSION          ...
# 68696  529  HEALTH AND HUMAN SERVICES COMMISSION          ...
# 68697  529  HEALTH AND HUMAN SERVICES COMMISSION          ...
#
#                              LASTNAME                       FIRSTNAME MI  \
# 10     TERRAZAS                        BRENDA
# 15     COURTNEY                        EMILY                           R
# 16     DAVIS                           BRITTANY                        T
# 17     GUYNES-SMITH                    JEWELIA                         A
# 20     KERN                            LYNN
# ...                               ...                             ... ..
# 68693  ZUNIGA - CHAMBLESS              STEPHANIE
# 68694  ZURFLUH                         ROBERT
# 68695  ZUROVETZ                        KATIE                           L
# 68696  ZWAHR                           PATRICIA                        L
# 68697  ZWERNEMAN                       CASEY                           R
#
#        JOBCLASS                                           JC TITLE  \
# 10     0173      LICENSE AND PERMIT SPEC IV                    ...
# 15     4421      LICENSED VOCATIONAL NURSE I                   ...
# 16     1325      INSPECTOR V                                   ...
# 17     0154      ADMINISTRATIVE ASST III                       ...
# 20     1018      ACCOUNTANT IV                                 ...
# ...         ...                                                ...
# 68693  1601      MGR II                                        ...
# 68694  4411      NURSE I                                       ...
# 68695  0230      SYSTEMS SUPPORT SPECIALIST III                ...
# 68696  1980      CONTRACT SPEC II                              ...
# 68697  1573      PROGRAM SPECIALIST IV                         ...
#
#                   RACE              SEX  \
# 10     HISPANIC         FEMALE
# 15     HISPANIC         FEMALE
# 16     BLACK            FEMALE
# 17     HISPANIC         FEMALE
# 20     ASIAN            FEMALE
# ...                ...              ...
# 68693  HISPANIC         FEMALE
# 68694  WHITE            MALE
# 68695  WHITE            MALE
# 68696  WHITE            FEMALE
# 68697  WHITE            FEMALE
#
#                                         EMPTYPE  ... RATE  HRSWKD  MONTHLY  \
# 10     CRF - CLASSIFIED REGULAR FULL-TIME        ...  0.0    40.0  3293.41
# 15     CRF - CLASSIFIED REGULAR FULL-TIME        ...  0.0    40.0  2771.81
# 16     CRF - CLASSIFIED REGULAR FULL-TIME        ...  0.0    40.0  4594.16
# 17     CRF - CLASSIFIED REGULAR FULL-TIME        ...  0.0    40.0  2748.00
# 20     CRF - CLASSIFIED REGULAR FULL-TIME        ...  0.0    40.0  4500.00
# ...                                         ...  ...  ...     ...      ...
# 68693  CRF - CLASSIFIED REGULAR FULL-TIME        ...  0.0    40.0  4920.57
# 68694  CRF - CLASSIFIED REGULAR FULL-TIME        ...  0.0    40.0  4966.12
# 68695  CRF - CLASSIFIED REGULAR FULL-TIME        ...  0.0    40.0  3100.00
# 68696  CRF - CLASSIFIED REGULAR FULL-TIME        ...  0.0    40.0  3081.33
# 68697  CRF - CLASSIFIED REGULAR FULL-TIME        ...  0.0    40.0  3857.24
#
#          ANNUAL  STATENUM  duplicated multiple_full_time_jobs  \
# 10     39520.92    193274        True                    True
# 15     33261.72   1273494        True                    True
# 16     55129.92    763078        True                    True
# 17     32976.00   1056073        True                    True
# 20     54000.00   1081409        True                    True
# ...         ...       ...         ...                     ...
# 68693  59046.84   1141763         NaN                     NaN
# 68694  59593.44   1272665         NaN                     NaN
# 68695  37200.00   1197447         NaN                     NaN
# 68696  36975.96    100439         NaN                     NaN
# 68697  46286.88   1151645         NaN                     NaN
#
#       combined_multiple_jobs summed_annual_salary  hide_from_search
# 10                       NaN                  NaN               NaN
# 15                       NaN                  NaN               NaN
# 16                       NaN                  NaN               NaN
# 17                       NaN                  NaN               NaN
# 20                       NaN                  NaN               NaN
# ...                      ...                  ...               ...
# 68693                    NaN                  NaN               NaN
# 68694                    NaN                  NaN               NaN
# 68695                    NaN                  NaN               NaN
# 68696                    NaN                  NaN               NaN
# 68697                    NaN                  NaN               NaN
#
# [34561 rows x 21 columns]

# %%
df.AGY.value_counts()
# Out:
# 529    34561
# 696    32961
# 601    13037
# 530    12568
# 405    10388
#        ...
# 513        8
# 364        7
# 514        7
# 481        5
# 213        4
# Name: AGY, Length: 111, dtype: int64

# %%
df.RACE.value_counts()
# Out:
# WHITE              64651
# HISPANIC           39557
# BLACK              33964
# ASIAN               4419
# OTHER               1453
# AM INDIAN            694
# Name: RACE, dtype: int64

# %%
df['JC TITLE'].value_counts()
# Out:
# CORREC  OFFICER IV                                    8753
# CORREC  OFFICER V                                     7350
# TEXAS WORKS ADVISOR II                                3812
# CORREC OFFCR III                                      3652
# DIRECT SUPPORT PROFESSIONAL I                         2484
#                                                       ...
# INVESTIGATIVE ANALYST                                    1
# EXECUTIVE DIRECTOR FOR ERS                               1
# MILITARY SPECIALIST V                                    1
# EXECUTIVE DIRECTOR/SECRETARY                             1
# ADMINISTRATIVE ASSISTANT IV                              1
# Name: JC TITLE, Length: 1406, dtype: int64

# %%
df = pr.prepare_tex(df)

# %%
df = pr.create_features(df)

# %%
df = pr.make_bins_and_feats(df)
# Out:
# Looking At Our Maximum Age and Minimum Age to Make Some Age Bins
#
# Max: 49.8, Min: 0.0
#
# ----------------------------
#
# Visualizing Years of Tenure Column To Help with Binning
# ----------------------------
#
# Looking At Our Years of Tenure Bins Value Counts
# 1    83012
# 2    27330
# 3    25513
# 4     8875
# Name: tenure_years_bins, dtype: int64
#
# ----------------------------

# %%
train, validate, test = pr.split_data(df)
# Out:
# Making Sure Our Shapes Look Good
# Train: (81048, 29), Validate: (34736, 29), Test: (28946, 29)

# %%
train.columns
# Out:
# Index(['agency_id', 'agency', 'lastname', 'firstname', 'title', 'race', 'sex',
#        'emptype', 'hire_date', 'hours_worked', 'monthly_salary',
#        'annual_salary', 'is_female', 'is_white', 'is_hispanic', 'is_black',
#        'is_BIPOC', 'race_encoded', 'tenure_months', 'tenure_years',
#        'is_elected', 'is_director', 'is_unclassified', 'is_parttime',
#        'tenure_years_bins', '0-5_years', '5-10_years', '10-20_years',
#        '>20_years'],
#       dtype='object')

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 81048 entries, 125096 to 89798
# Data columns (total 29 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   agency_id          81048 non-null  int64
#  1   agency             81048 non-null  object
#  2   lastname           81048 non-null  object
#  3   firstname          81048 non-null  object
#  4   title              81048 non-null  object
#  5   race               81048 non-null  object
#  6   sex                81048 non-null  object
#  7   emptype            81048 non-null  object
#  8   hire_date          81048 non-null  datetime64[ns]
#  9   hours_worked       81048 non-null  float64
#  10  monthly_salary     81048 non-null  float64
#  11  annual_salary      81048 non-null  float64
#  12  is_female          81048 non-null  int64
#  13  is_white           81048 non-null  int64
#  14  is_hispanic        81048 non-null  int64
#  15  is_black           81048 non-null  int64
#  16  is_BIPOC           81048 non-null  int64
#  17  race_encoded       81048 non-null  int64
#  18  tenure_months      81048 non-null  int64
#  19  tenure_years       81048 non-null  float64
#  20  is_elected         81048 non-null  int64
#  21  is_director        81048 non-null  int64
#  22  is_unclassified    81048 non-null  int64
#  23  is_parttime        81048 non-null  int64
#  24  tenure_years_bins  81048 non-null  int64
#  25  0-5_years          81048 non-null  int64
#  26  5-10_years         81048 non-null  int64
#  27  10-20_years        81048 non-null  int64
#  28  >20_years          81048 non-null  int64
# dtypes: datetime64[ns](1), float64(4), int64(17), object(7)
# memory usage: 18.6+ MB

# %%
# assign X and y variables in all our split dfs
X_train = train[['agency_id', 'hours_worked','is_female', 'is_white', 
                'is_hispanic', 'is_black', 'is_BIPOC', 'race_encoded', 'tenure_months',
                'tenure_years', 'is_elected', 'is_director', 'is_unclassified', 'is_parttime','tenure_years_bins', '0-5_years', '5-10_years', '10-20_years',
       '>20_years' ]]
y_train = train[['annual_salary']]

X_validate = validate[['agency_id', 'hours_worked','is_female', 'is_white', 
                'is_hispanic', 'is_black', 'is_BIPOC', 'race_encoded', 'tenure_months',
                'tenure_years', 'is_elected', 'is_director', 'is_unclassified', 'is_parttime','tenure_years_bins', '0-5_years', '5-10_years', '10-20_years',
       '>20_years']]
y_validate = validate[['annual_salary']]

X_test = test[['agency_id', 'hours_worked','is_female', 'is_white', 
                'is_hispanic', 'is_black', 'is_BIPOC', 'race_encoded', 'tenure_months',
                'tenure_years', 'is_elected', 'is_director', 'is_unclassified', 'is_parttime','tenure_years_bins', '0-5_years', '5-10_years', '10-20_years',
       '>20_years']]
y_test = test[['annual_salary']]

# %%
def select_rfe(X, y, k, return_rankings=False, model=LinearRegression()):
    '''
    This function takes in the X variables as a dataframe, the target variable, number of features to 
    select for modeling (k) with default modle set to Linear Regression. It returns the top k features 
    as well as the rankings for all features.
    '''
    # Use the passed model, LinearRegression by default
    rfe = RFE(model, n_features_to_select=k)
    rfe.fit(X, y)
    features = X.columns[rfe.support_].tolist()
    if return_rankings:
        rankings = pd.Series(dict(zip(X.columns, rfe.ranking_)))
        return features, rankings
    else:
        return features

# %%
# call rfe function from explore script
features_to_use, feature_rankings = select_rfe(X_train, y_train, 7, return_rankings=True)

# %%
features_to_use
# Out:
# ['is_white',
#  'is_BIPOC',
#  'is_director',
#  'tenure_years_bins',
#  '0-5_years',
#  '5-10_years',
#  '>20_years']

# %%
features = ['is_white',
 'is_black',
 'is_BIPOC',
 'race_encoded',
 'is_director',
 'is_unclassified',
 'is_parttime']

# %%
# 1. Predict mean annual 
sal_pred_mean = y_train.annual_salary.mean()
y_train['sal_pred_mean'] = sal_pred_mean
y_validate['sal_pred_mean'] = sal_pred_mean

# 2. Predict median tax value 
sal_pred_median = y_train.annual_salary.median()
y_train['sal_pred_median'] = sal_pred_median
y_validate['sal_pred_median'] = sal_pred_median

# 3. RMSE of tv_pred_mean
rmse_train = mean_squared_error(y_train.annual_salary, y_train.sal_pred_mean) ** 0.5
rmse_validate = mean_squared_error(y_validate.annual_salary, y_validate.sal_pred_mean) ** 0.5

print("RMSE using Mean\nTrain/In-Sample: ", round(rmse_train, 5), 
      "\nValidate/Out-of-Sample: ", round(rmse_validate, 5))

# 4. RMSE of tv_pred_median
rmse_train1 = mean_squared_error(y_train.annual_salary, y_train.sal_pred_median) ** .5
rmse_validate1 = mean_squared_error(y_validate.annual_salary, y_validate.sal_pred_median) ** .5
print('-----------')
print("RMSE using Median\nTrain/In-Sample: ", round(rmse_train1, 5), 
      "\nValidate/Out-of-Sample: ", round(rmse_validate1, 5))
# Out:
# RMSE using Mean
# Train/In-Sample:  25758.77625
# Validate/Out-of-Sample:  25431.1923
# -----------
# RMSE using Median
# Train/In-Sample:  26727.62101
# Validate/Out-of-Sample:  26448.16247

# %%
# add the mean baseline to a df to help evaluate all models side by side
metric_df = pd.DataFrame(data=[{
    'model': 'median_baseline',
    'rmse_outofsample': rmse_validate1,
    'r^2_outofsample': explained_variance_score(y_validate.annual_salary, y_validate.sal_pred_median)}])

# %% [markdown]
# ## OLS Linear Regression

# %%
# create the model object

lm = LinearRegression(fit_intercept=True)

# fit the model to our training data. We must specify the column in y_train, since we have converted it to a dataframe from a series! 

# fit the thing using only the features we selected
lm.fit(X_train[features], y_train.annual_salary)

# predict train

y_train['sal_pred_lm'] = lm.predict(X_train[features])

# evaluate: rmse
rmse_train = mean_squared_error(y_train.annual_salary, y_train.sal_pred_lm) ** (1/2)

# predict validate
y_validate['sal_pred_lm'] = lm.predict(X_validate[features])

# evaluate: rmse
rmse_validate = mean_squared_error(y_validate.annual_salary, y_validate.sal_pred_lm) ** (1/2)

print("RMSE for OLS using LinearRegression\nTraining/In-Sample: ", rmse_train, 
      "\nValidation/Out-of-Sample: ", rmse_validate)
# Out:
# RMSE for OLS using LinearRegression
# Training/In-Sample:  22691.164842289778
# Validation/Out-of-Sample:  22537.912412970338

# %%
# add model's performance to metric df
metric_df = metric_df.append(
    {
    'model': 'OLS lm',
    'rmse_outofsample': rmse_validate,
        'r^2_outofsample': explained_variance_score(y_validate.annual_salary, y_validate.sal_pred_lm)}, ignore_index=True)

# %%
metric_df
# Out:
#              model  rmse_outofsample  r^2_outofsample
# 0  median_baseline      26448.162472         0.000000
# 1           OLS lm      22537.912413         0.214656

# %% [markdown]
# ## Lasso Lars Model

# %%
# create the model object
lars = LassoLars(alpha=1)

# fit the model to our training data using only selected features. We must specify the column in y_train, 
# since we have converted it to a dataframe from a series
lars.fit(X_train[features], y_train.annual_salary)

# predict train
y_train['sal_pred_lars'] = lars.predict(X_train[features])

# evaluate: rmse
rmse_train = mean_squared_error(y_train.annual_salary, y_train.sal_pred_lars) ** 0.5

# predict validate
y_validate['sal_pred_lars'] = lars.predict(X_validate[features])

# evaluate: rmse
rmse_validate = mean_squared_error(y_validate.annual_salary, y_validate.sal_pred_lars) ** 0.5

print("RMSE for Lasso + Lars\nTraining/In-Sample: ", rmse_train, 
      "\nValidation/Out-of-Sample: ", rmse_validate)
# Out:
# RMSE for Lasso + Lars
# Training/In-Sample:  22784.01463715798
# Validation/Out-of-Sample:  22652.214468088205

# %%
# add model to metric df
metric_df = metric_df.append(
    {
    'model': 'LassoLars alpha 1',
    'rmse_outofsample': rmse_validate,
    'r^2_outofsample': explained_variance_score(y_validate.annual_salary, y_validate.sal_pred_lars)}, ignore_index=True)

# %%
metric_df
# Out:
#                model  rmse_outofsample  r^2_outofsample
# 0    median_baseline      26448.162472         0.000000
# 1             OLS lm      22537.912413         0.214656
# 2  LassoLars alpha 1      22652.214468         0.206668

# %% [markdown]
# ## Tweedie Regressor GLM

# %%
# create the model object
glm = TweedieRegressor(power=0, alpha=1)

# fit the model to our training data using only selected features. We must specify the column in y_train, 
# since we have converted it to a dataframe from a series

glm.fit(X_train[features], y_train.annual_salary)

# predict train
y_train['sal_pred_glm'] = glm.predict(X_train[features])

# evaluate: rmse
rmse_train = mean_squared_error(y_train.annual_salary, y_train.sal_pred_glm) ** 0.5


# predict validate
y_validate['sal_pred_glm'] = glm.predict(X_validate[features])

# evaluate: rmse
rmse_validate = mean_squared_error(y_validate.annual_salary, y_validate.sal_pred_glm) ** 0.5

print("RMSE for GLM using Tweedie, power=1 & alpha=0\nTraining/In-Sample: ", rmse_train, 
      "\nValidation/Out-of-Sample: ", rmse_validate)
# Out:
# RMSE for GLM using Tweedie, power=1 & alpha=0
# Training/In-Sample:  25286.856783650972
# Validation/Out-of-Sample:  24964.30475013445

# %%
# add model to metric df
metric_df = metric_df.append(
    {
    'model': 'Tweedie GLM power 1',
    'rmse_outofsample': rmse_validate,
    'r^2_outofsample': explained_variance_score(y_validate.annual_salary, y_validate.sal_pred_glm)}, ignore_index=True)

# %%
metric_df
# Out:
#                  model  rmse_outofsample  r^2_outofsample
# 0      median_baseline      26448.162472         0.000000
# 1               OLS lm      22537.912413         0.214656
# 2    LassoLars alpha 1      22652.214468         0.206668
# 3  Tweedie GLM power 1      24964.304750         0.036377

# %% [markdown]
# ## 2nd degree Polynomial Regression Model

# %%
# make the polynomial features to get a new set of features
pf = PolynomialFeatures(degree=2)

# fit and transform X_train_scaled features
X_train_degree2 = pf.fit_transform(X_train[features])

# transform X_validate_scaled & X_test_scaled
X_validate_degree2 = pf.transform(X_validate[features])
X_test_degree2 = pf.transform(X_test[features])

# %%
#create the model object

pm = LinearRegression(normalize=True)

# fit the model to our training data. We must specify the column in y_train, 
# since we have converted it to a dataframe from a series! 

# fit the thing

pm.fit(X_train_degree2, y_train.annual_salary)

# predict train

y_train['sal_pred_pm'] = pm.predict(X_train_degree2)

# evaluate: rmse
rmse_train = mean_squared_error(y_train.annual_salary, y_train.sal_pred_pm) ** (1/2)

# predict validate
y_validate['sal_pred_pm'] = pm.predict(X_validate_degree2)

# evaluate: rmse
rmse_validate = mean_squared_error(y_validate.annual_salary, y_validate.sal_pred_pm) ** (1/2)

print("RMSE for PolynomialRegression\nTraining/In-Sample: ", rmse_train, 
      "\nValidation/Out-of-Sample: ", rmse_validate)
# Out:
# RMSE for PolynomialRegression
# Training/In-Sample:  22596.139469732876
# Validation/Out-of-Sample:  22430.595041676057

# %%
# add model to metric df
metric_df = metric_df.append(
    {
    'model': 'PolyReg Model',
    'rmse_outofsample': rmse_validate,
    'r^2_outofsample': explained_variance_score(y_validate.annual_salary, y_validate.sal_pred_pm)}, ignore_index=True)
metric_df
# Out:
#                  model  rmse_outofsample  r^2_outofsample
# 0      median_baseline      26448.162472         0.000000
# 1               OLS lm      22537.912413         0.214656
# 2    LassoLars alpha 1      22652.214468         0.206668
# 3  Tweedie GLM power 1      24964.304750         0.036377
# 4        PolyReg Model      22430.595042         0.222114

# %% [markdown]
# ## third degree polynomial

# %%
# make the polynomial features to get a new set of features
pf3 = PolynomialFeatures(degree=3)

# fit and transform X_train_scaled features
X_train_degree3 = pf.fit_transform(X_train[features])

# transform X_validate_scaled & X_test_scaled
X_validate_degree3 = pf.transform(X_validate[features])
X_test_degree3 = pf.transform(X_test[features])

# %%
#create the model object

pm3 = LinearRegression(normalize=True)

# fit the model to our training data. We must specify the column in y_train, 
# since we have converted it to a dataframe from a series! 

# fit the thing

pm3.fit(X_train_degree3, y_train.annual_salary)

# predict train

y_train['sal_pred_pm3'] = pm3.predict(X_train_degree3)

# evaluate: rmse
rmse_train = mean_squared_error(y_train.annual_salary, y_train.sal_pred_pm3) ** (1/2)

# predict validate
y_validate['sal_pred_pm3'] = pm3.predict(X_validate_degree3)

# evaluate: rmse
rmse_validate = mean_squared_error(y_validate.annual_salary, y_validate.sal_pred_pm3) ** (1/2)

print("RMSE for PolynomialRegression\nTraining/In-Sample: ", rmse_train, 
      "\nValidation/Out-of-Sample: ", rmse_validate)
# Out:
# RMSE for PolynomialRegression
# Training/In-Sample:  22596.139469732876
# Validation/Out-of-Sample:  22430.595041676057

# %%
# add model to metric df
metric_df = metric_df.append(
    {
    'model': 'PolyReg Model',
    'rmse_outofsample': rmse_validate,
    'r^2_outofsample': explained_variance_score(y_validate.annual_salary, y_validate.sal_pred_pm3)}, ignore_index=True)
metric_df
# Out:
#                  model  rmse_outofsample  r^2_outofsample
# 0      median_baseline      26448.162472         0.000000
# 1               OLS lm      22537.912413         0.214656
# 2    LassoLars alpha 1      22652.214468         0.206668
# 3  Tweedie GLM power 1      24964.304750         0.036377
# 4        PolyReg Model      22430.595042         0.222114
# 5        PolyReg Model      22430.595042         0.222114

# %% [markdown]
# ## Fitting on Test Split

# %%
# predict on test
y_test['sal_pred_pm'] = pm.predict(X_test_degree2)

# evaluate: rmse
rmse_test = mean_squared_error(y_test.annual_salary, y_test.sal_pred_pm) ** 0.5
print("RMSE for Model using PolynomialRegression\nOut-of-Sample Performance: ", rmse_test)
# Out:
# RMSE for Model using PolynomialRegression
# Out-of-Sample Performance:  22297.326171611105

# %%
metric_df = metric_df.append(
    {
    'model': 'Test',
    'rmse_outofsample': rmse_test,
    'r^2_outofsample': explained_variance_score(y_test.annual_salary, y_test.sal_pred_pm)}, ignore_index=True)

# %%
metric_df
# Out:
#                  model  rmse_outofsample  r^2_outofsample
# 0      median_baseline      26448.162472         0.000000
# 1               OLS lm      22537.912413         0.214656
# 2    LassoLars alpha 1      22652.214468         0.206668
# 3  Tweedie GLM power 1      24964.304750         0.036377
# 4        PolyReg Model      22430.595042         0.222114
# 5        PolyReg Model      22430.595042         0.222114
# 6                 Test      22297.326172         0.243110

# %%
df.columns
# Out:
# Index(['agency_id', 'agency', 'lastname', 'firstname', 'title', 'race', 'sex',
#        'emptype', 'hire_date', 'hours_worked', 'monthly_salary',
#        'annual_salary', 'is_female', 'is_white', 'is_hispanic', 'is_black',
#        'is_BIPOC', 'race_encoded', 'tenure_months', 'tenure_years',
#        'is_elected', 'is_director', 'is_unclassified', 'is_parttime'],
#       dtype='object')

# %%
train.columns
# Out:
# Index(['agency_id', 'agency', 'lastname', 'firstname', 'title', 'race', 'sex',
#        'emptype', 'hire_date', 'hours_worked', 'monthly_salary',
#        'annual_salary', 'is_female', 'is_white', 'is_hispanic', 'is_black',
#        'is_BIPOC', 'race_encoded', 'tenure_months', 'tenure_years',
#        'is_elected', 'is_director', 'is_unclassified', 'is_parttime'],
#       dtype='object')

# %%
## change features and reiterate

features = ['is_white',
 'is_black',
 'is_BIPOC',
 'race_encoded',
 'is_director',
 'is_unclassified',
 'is_parttime', 'tenure_months','agency_id','tenure_years']

# %%
# 1. Predict mean annual 
sal_pred_mean = y_train.annual_salary.mean()
y_train['sal_pred_mean'] = sal_pred_mean
y_validate['sal_pred_mean'] = sal_pred_mean

# 2. Predict median tax value 
sal_pred_median = y_train.annual_salary.median()
y_train['sal_pred_median'] = sal_pred_median
y_validate['sal_pred_median'] = sal_pred_median

# 3. RMSE of tv_pred_mean
rmse_train = mean_squared_error(y_train.annual_salary, y_train.sal_pred_mean) ** 0.5
rmse_validate = mean_squared_error(y_validate.annual_salary, y_validate.sal_pred_mean) ** 0.5

print("RMSE using Mean\nTrain/In-Sample: ", round(rmse_train, 5), 
      "\nValidate/Out-of-Sample: ", round(rmse_validate, 5))

# 4. RMSE of tv_pred_median
rmse_train1 = mean_squared_error(y_train.annual_salary, y_train.sal_pred_median) ** .5
rmse_validate1 = mean_squared_error(y_validate.annual_salary, y_validate.sal_pred_median) ** .5
print('-----------')
print("RMSE using Median\nTrain/In-Sample: ", round(rmse_train1, 5), 
      "\nValidate/Out-of-Sample: ", round(rmse_validate1, 5))
# Out:
# RMSE using Mean
# Train/In-Sample:  25758.77625
# Validate/Out-of-Sample:  25431.1923
# -----------
# RMSE using Median
# Train/In-Sample:  26727.62101
# Validate/Out-of-Sample:  26448.16247

# %%
# ols
# create the model object

lm = LinearRegression(fit_intercept=True)

# fit the model to our training data. We must specify the column in y_train, since we have converted it to a dataframe from a series! 

# fit the thing using only the features we selected
lm.fit(X_train[features], y_train.annual_salary)

# predict train

y_train['sal_pred_lm'] = lm.predict(X_train[features])

# evaluate: rmse
rmse_train = mean_squared_error(y_train.annual_salary, y_train.sal_pred_lm) ** (1/2)

# predict validate
y_validate['sal_pred_lm'] = lm.predict(X_validate[features])

# evaluate: rmse
rmse_validate = mean_squared_error(y_validate.annual_salary, y_validate.sal_pred_lm) ** (1/2)

print("RMSE for OLS using LinearRegression\nTraining/In-Sample: ", rmse_train, 
      "\nValidation/Out-of-Sample: ", rmse_validate)
# Out:
# RMSE for OLS using LinearRegression
# Training/In-Sample:  21187.621559250158
# Validation/Out-of-Sample:  20911.988826466102

# %%
# add model's performance to metric df
metric_df = metric_df.append(
    {
    'model': 'OLS lm',
    'rmse_outofsample': rmse_validate,
        'r^2_outofsample': explained_variance_score(y_validate.annual_salary, y_validate.sal_pred_lm)}, ignore_index=True)

# %%
metric_df
# Out:
#                  model  rmse_outofsample  r^2_outofsample
# 0      median_baseline      26448.162472         0.000000
# 1               OLS lm      22537.912413         0.214656
# 2    LassoLars alpha 1      22652.214468         0.206668
# 3  Tweedie GLM power 1      24964.304750         0.036377
# 4        PolyReg Model      22430.595042         0.222114
# 5        PolyReg Model      22430.595042         0.222114
# 6                 Test      22297.326172         0.243110
# 7               OLS lm      20911.988826         0.323853

# %%
# lasso lars
# create the model object
lars = LassoLars(alpha=1)

# fit the model to our training data using only selected features. We must specify the column in y_train, 
# since we have converted it to a dataframe from a series
lars.fit(X_train[features], y_train.annual_salary)

# predict train
y_train['sal_pred_lars'] = lars.predict(X_train[features])

# evaluate: rmse
rmse_train = mean_squared_error(y_train.annual_salary, y_train.sal_pred_lars) ** 0.5

# predict validate
y_validate['sal_pred_lars'] = lars.predict(X_validate[features])

# evaluate: rmse
rmse_validate = mean_squared_error(y_validate.annual_salary, y_validate.sal_pred_lars) ** 0.5

print("RMSE for Lasso + Lars\nTraining/In-Sample: ", rmse_train, 
      "\nValidation/Out-of-Sample: ", rmse_validate)
# Out:
# RMSE for Lasso + Lars
# Training/In-Sample:  21361.82047604373
# Validation/Out-of-Sample:  21104.629353226184

# %%
# add model to metric df
metric_df = metric_df.append(
    {
    'model': 'LassoLars alpha 1',
    'rmse_outofsample': rmse_validate,
    'r^2_outofsample': explained_variance_score(y_validate.annual_salary, y_validate.sal_pred_lars)}, ignore_index=True)

# %%
# glm
# create the model object
glm = TweedieRegressor(power=0, alpha=1)

# fit the model to our training data using only selected features. We must specify the column in y_train, 
# since we have converted it to a dataframe from a series

glm.fit(X_train[features], y_train.annual_salary)

# predict train
y_train['sal_pred_glm'] = glm.predict(X_train[features])

# evaluate: rmse
rmse_train = mean_squared_error(y_train.annual_salary, y_train.sal_pred_glm) ** 0.5


# predict validate
y_validate['sal_pred_glm'] = glm.predict(X_validate[features])

# evaluate: rmse
rmse_validate = mean_squared_error(y_validate.annual_salary, y_validate.sal_pred_glm) ** 0.5

print("RMSE for GLM using Tweedie, power=1 & alpha=0\nTraining/In-Sample: ", rmse_train, 
      "\nValidation/Out-of-Sample: ", rmse_validate)
# Out:
# RMSE for GLM using Tweedie, power=1 & alpha=0
# Training/In-Sample:  23459.332630575787
# Validation/Out-of-Sample:  23027.47170846243

# %%
# add model to metric df
metric_df = metric_df.append(
    {
    'model': 'Tweedie GLM power 1',
    'rmse_outofsample': rmse_validate,
    'r^2_outofsample': explained_variance_score(y_validate.annual_salary, y_validate.sal_pred_glm)}, ignore_index=True)

# %%
# 2nd deg polynomial
# make the polynomial features to get a new set of features
pf = PolynomialFeatures(degree=2)

# fit and transform X_train_scaled features
X_train_degree2 = pf.fit_transform(X_train[features])

# transform X_validate_scaled & X_test_scaled
X_validate_degree2 = pf.transform(X_validate[features])
X_test_degree2 = pf.transform(X_test[features])

# %%
#create the model object

pm = LinearRegression(normalize=True)

# fit the model to our training data. We must specify the column in y_train, 
# since we have converted it to a dataframe from a series! 

# fit the thing

pm.fit(X_train_degree2, y_train.annual_salary)

# predict train

y_train['sal_pred_pm'] = pm.predict(X_train_degree2)

# evaluate: rmse
rmse_train = mean_squared_error(y_train.annual_salary, y_train.sal_pred_pm) ** (1/2)

# predict validate
y_validate['sal_pred_pm'] = pm.predict(X_validate_degree2)

# evaluate: rmse
rmse_validate = mean_squared_error(y_validate.annual_salary, y_validate.sal_pred_pm) ** (1/2)

print("RMSE for PolynomialRegression\nTraining/In-Sample: ", rmse_train, 
      "\nValidation/Out-of-Sample: ", rmse_validate)
# Out:
# RMSE for PolynomialRegression
# Training/In-Sample:  20585.75238309553
# Validation/Out-of-Sample:  20290.719726405172

# %%
# add model to metric df
metric_df = metric_df.append(
    {
    'model': 'PolyReg Model',
    'rmse_outofsample': rmse_validate,
    'r^2_outofsample': explained_variance_score(y_validate.annual_salary, y_validate.sal_pred_pm)}, ignore_index=True)
metric_df
# Out:
#                   model  rmse_outofsample  r^2_outofsample
# 0       median_baseline      26448.162472         0.000000
# 1                OLS lm      22537.912413         0.214656
# 2     LassoLars alpha 1      22652.214468         0.206668
# 3   Tweedie GLM power 1      24964.304750         0.036377
# 4         PolyReg Model      22430.595042         0.222114
# 5         PolyReg Model      22430.595042         0.222114
# 6                  Test      22297.326172         0.243110
# 7                OLS lm      20911.988826         0.323853
# 8     LassoLars alpha 1      21104.629353         0.311349
# 9   Tweedie GLM power 1      23027.471708         0.180084
# 10        PolyReg Model      20290.719726         0.363431

# %%
# third deg polynomial
# make the polynomial features to get a new set of features
pf3 = PolynomialFeatures(degree=3)

# fit and transform X_train_scaled features
X_train_degree3 = pf.fit_transform(X_train[features])

# transform X_validate_scaled & X_test_scaled
X_validate_degree3 = pf.transform(X_validate[features])
X_test_degree3 = pf.transform(X_test[features])

# %%
#create the model object

pm3 = LinearRegression(normalize=True)

# fit the model to our training data. We must specify the column in y_train, 
# since we have converted it to a dataframe from a series! 

# fit the thing

pm3.fit(X_train_degree3, y_train.annual_salary)

# predict train

y_train['sal_pred_pm3'] = pm3.predict(X_train_degree3)

# evaluate: rmse
rmse_train = mean_squared_error(y_train.annual_salary, y_train.sal_pred_pm3) ** (1/2)

# predict validate
y_validate['sal_pred_pm3'] = pm3.predict(X_validate_degree3)

# evaluate: rmse
rmse_validate = mean_squared_error(y_validate.annual_salary, y_validate.sal_pred_pm3) ** (1/2)

print("RMSE for PolynomialRegression\nTraining/In-Sample: ", rmse_train, 
      "\nValidation/Out-of-Sample: ", rmse_validate)
# Out:
# RMSE for PolynomialRegression
# Training/In-Sample:  20585.75238309553
# Validation/Out-of-Sample:  20290.719726405172

# %%
# add model to metric df
metric_df = metric_df.append(
    {
    'model': 'PolyReg Model',
    'rmse_outofsample': rmse_validate,
    'r^2_outofsample': explained_variance_score(y_validate.annual_salary, y_validate.sal_pred_pm3)}, ignore_index=True)
metric_df
# Out:
#                   model  rmse_outofsample  r^2_outofsample
# 0       median_baseline      26448.162472         0.000000
# 1                OLS lm      22537.912413         0.214656
# 2     LassoLars alpha 1      22652.214468         0.206668
# 3   Tweedie GLM power 1      24964.304750         0.036377
# 4         PolyReg Model      22430.595042         0.222114
# 5         PolyReg Model      22430.595042         0.222114
# 6                  Test      22297.326172         0.243110
# 7                OLS lm      20911.988826         0.323853
# 8     LassoLars alpha 1      21104.629353         0.311349
# 9   Tweedie GLM power 1      23027.471708         0.180084
# 10        PolyReg Model      20290.719726         0.363431
# 11        PolyReg Model      20290.719726         0.363431

# %%
# best model 2nd deg polynomial fit on test

# predict on test
y_test['sal_pred_pm'] = pm.predict(X_test_degree2)

# evaluate: rmse
rmse_test = mean_squared_error(y_test.annual_salary, y_test.sal_pred_pm) ** 0.5
print("RMSE for Model using PolynomialRegression\nOut-of-Sample Performance: ", rmse_test)
# Out:
# RMSE for Model using PolynomialRegression
# Out-of-Sample Performance:  20108.90496523264

# %%
metric_df = metric_df.append(
    {
    'model': 'Test',
    'rmse_outofsample': rmse_test,
    'r^2_outofsample': explained_variance_score(y_test.annual_salary, y_test.sal_pred_pm)}, ignore_index=True)

# %%
metric_df
# Out:
#                   model  rmse_outofsample  r^2_outofsample
# 0       median_baseline      26448.162472         0.000000
# 1                OLS lm      22537.912413         0.214656
# 2     LassoLars alpha 1      22652.214468         0.206668
# 3   Tweedie GLM power 1      24964.304750         0.036377
# 4         PolyReg Model      22430.595042         0.222114
# 5         PolyReg Model      22430.595042         0.222114
# 6                  Test      22297.326172         0.243110
# 7                OLS lm      20911.988826         0.323853
# 8     LassoLars alpha 1      21104.629353         0.311349
# 9   Tweedie GLM power 1      23027.471708         0.180084
# 10        PolyReg Model      20290.719726         0.363431
# 11        PolyReg Model      20290.719726         0.363431
# 12                 Test      20108.904965         0.384399

# %%
# plot the residuals for the best performing model

plt.figure(figsize=(16,8))
plt.axhline(label="No Error")

plt.scatter(y_validate.annual_salary, y_validate.sal_pred_pm - y_validate.annual_salary, 
            alpha=.5, color="green", s=100, label="Model 2nd degree Polynomial")
plt.legend()
plt.xlabel("Actual Annual Salary")
plt.ylabel("Residual/Error: Predicted Salary - Actual")
plt.title("Do the size of errors change as the actual value changes?")

plt.show()

# %%
# plot to visualize actual vs predicted values
plt.figure(figsize=(16,8))
plt.hist(y_validate.annual_salary, color='blue', alpha=.5, label="Actual Salaries")
plt.hist(y_validate.sal_pred_pm, color='green', alpha=.5, label="Model 2nd degree Polynomial")
plt.xlabel("Annual Salary")
plt.ylabel("Number of Employees")
plt.title("Comparing the Distribution of Actual salaries to Distributions of Predicted salaries for the Top Model")
plt.legend()
plt.show()

# %%
features =['is_white',
 'is_BIPOC',
 'is_director',
 'tenure_years_bins',
 '0-5_years',
 '5-10_years',
 '>20_years','is_unclassified',
 'is_parttime', 'agency_id']

# %%
# ols
# create the model object

lm = LinearRegression(fit_intercept=True)

# fit the model to our training data. We must specify the column in y_train, since we have converted it to a dataframe from a series! 

# fit the thing using only the features we selected
lm.fit(X_train[features], y_train.annual_salary)

# predict train

y_train['sal_pred_lm'] = lm.predict(X_train[features])

# evaluate: rmse
rmse_train = mean_squared_error(y_train.annual_salary, y_train.sal_pred_lm) ** (1/2)

# predict validate
y_validate['sal_pred_lm'] = lm.predict(X_validate[features])

# evaluate: rmse
rmse_validate = mean_squared_error(y_validate.annual_salary, y_validate.sal_pred_lm) ** (1/2)

print("RMSE for OLS using LinearRegression\nTraining/In-Sample: ", rmse_train, 
      "\nValidation/Out-of-Sample: ", rmse_validate)
# Out:
# RMSE for OLS using LinearRegression
# Training/In-Sample:  21384.085894911164
# Validation/Out-of-Sample:  21144.233715975577

# %%
# add model's performance to metric df
metric_df = metric_df.append(
    {
    'model': 'OLS lm',
    'rmse_outofsample': rmse_validate,
        'r^2_outofsample': explained_variance_score(y_validate.annual_salary, y_validate.sal_pred_lm)}, ignore_index=True)

# %%
# lasso lars

# create the model object
lars = LassoLars(alpha=1)

# fit the model to our training data using only selected features. We must specify the column in y_train, 
# since we have converted it to a dataframe from a series
lars.fit(X_train[features], y_train.annual_salary)

# predict train
y_train['sal_pred_lars'] = lars.predict(X_train[features])

# evaluate: rmse
rmse_train = mean_squared_error(y_train.annual_salary, y_train.sal_pred_lars) ** 0.5

# predict validate
y_validate['sal_pred_lars'] = lars.predict(X_validate[features])

# evaluate: rmse
rmse_validate = mean_squared_error(y_validate.annual_salary, y_validate.sal_pred_lars) ** 0.5

print("RMSE for Lasso + Lars\nTraining/In-Sample: ", rmse_train, 
      "\nValidation/Out-of-Sample: ", rmse_validate)
# Out:
# RMSE for Lasso + Lars
# Training/In-Sample:  21634.406205511244
# Validation/Out-of-Sample:  21417.74076822995

# %%
# add model to metric df
metric_df = metric_df.append(
    {
    'model': 'LassoLars alpha 1',
    'rmse_outofsample': rmse_validate,
    'r^2_outofsample': explained_variance_score(y_validate.annual_salary, y_validate.sal_pred_lars)}, ignore_index=True)

# %%
# glm
# create the model object
glm = TweedieRegressor(power=0, alpha=1)

# fit the model to our training data using only selected features. We must specify the column in y_train, 
# since we have converted it to a dataframe from a series

glm.fit(X_train[features], y_train.annual_salary)

# predict train
y_train['sal_pred_glm'] = glm.predict(X_train[features])

# evaluate: rmse
rmse_train = mean_squared_error(y_train.annual_salary, y_train.sal_pred_glm) ** 0.5


# predict validate
y_validate['sal_pred_glm'] = glm.predict(X_validate[features])

# evaluate: rmse
rmse_validate = mean_squared_error(y_validate.annual_salary, y_validate.sal_pred_glm) ** 0.5

print("RMSE for GLM using Tweedie, power=1 & alpha=0\nTraining/In-Sample: ", rmse_train, 
      "\nValidation/Out-of-Sample: ", rmse_validate)
# Out:
# RMSE for GLM using Tweedie, power=1 & alpha=0
# Training/In-Sample:  23787.892263574508
# Validation/Out-of-Sample:  23393.862149015047

# %%
# add model to metric df
metric_df = metric_df.append(
    {
    'model': 'Tweedie GLM power 1',
    'rmse_outofsample': rmse_validate,
    'r^2_outofsample': explained_variance_score(y_validate.annual_salary, y_validate.sal_pred_glm)}, ignore_index=True)

# %%
# 2nd deg polynomial
# make the polynomial features to get a new set of features
pf = PolynomialFeatures(degree=2)

# fit and transform X_train_scaled features
X_train_degree2 = pf.fit_transform(X_train[features])

# transform X_validate_scaled & X_test_scaled
X_validate_degree2 = pf.transform(X_validate[features])
X_test_degree2 = pf.transform(X_test[features])

# %%
#create the model object

pm = LinearRegression(normalize=True)

# fit the model to our training data. We must specify the column in y_train, 
# since we have converted it to a dataframe from a series! 

# fit the thing

pm.fit(X_train_degree2, y_train.annual_salary)

# predict train

y_train['sal_pred_pm'] = pm.predict(X_train_degree2)

# evaluate: rmse
rmse_train = mean_squared_error(y_train.annual_salary, y_train.sal_pred_pm) ** (1/2)

# predict validate
y_validate['sal_pred_pm'] = pm.predict(X_validate_degree2)

# evaluate: rmse
rmse_validate = mean_squared_error(y_validate.annual_salary, y_validate.sal_pred_pm) ** (1/2)

print("RMSE for PolynomialRegression\nTraining/In-Sample: ", rmse_train, 
      "\nValidation/Out-of-Sample: ", rmse_validate)
# Out:
# RMSE for PolynomialRegression
# Training/In-Sample:  20946.689972325836
# Validation/Out-of-Sample:  20655.548766283388

# %%
# add model to metric df
metric_df = metric_df.append(
    {
    'model': 'PolyReg Model',
    'rmse_outofsample': rmse_validate,
    'r^2_outofsample': explained_variance_score(y_validate.annual_salary, y_validate.sal_pred_pm)}, ignore_index=True)
metric_df
# Out:
#                   model  rmse_outofsample  r^2_outofsample
# 0       median_baseline      26448.162472         0.000000
# 1                OLS lm      22537.912413         0.214656
# 2     LassoLars alpha 1      22652.214468         0.206668
# 3   Tweedie GLM power 1      24964.304750         0.036377
# 4         PolyReg Model      22430.595042         0.222114
# 5         PolyReg Model      22430.595042         0.222114
# 6                  Test      22297.326172         0.243110
# 7                OLS lm      20911.988826         0.323853
# 8     LassoLars alpha 1      21104.629353         0.311349
# 9   Tweedie GLM power 1      23027.471708         0.180084
# 10        PolyReg Model      20290.719726         0.363431
# 11        PolyReg Model      20290.719726         0.363431
# 12                 Test      20108.904965         0.384399
# 13               OLS lm      21144.233716         0.308748
# 14    LassoLars alpha 1      21417.740768         0.290758
# 15  Tweedie GLM power 1      23393.862149         0.153787
# 16        PolyReg Model      20655.548766         0.340334

# %%
# third deg polynomial
# make the polynomial features to get a new set of features
pf3 = PolynomialFeatures(degree=3)

# fit and transform X_train_scaled features
X_train_degree3 = pf.fit_transform(X_train[features])

# transform X_validate_scaled & X_test_scaled
X_validate_degree3 = pf.transform(X_validate[features])
X_test_degree3 = pf.transform(X_test[features])

# %%
#create the model object

pm3 = LinearRegression(normalize=True)

# fit the model to our training data. We must specify the column in y_train, 
# since we have converted it to a dataframe from a series! 

# fit the thing

pm3.fit(X_train_degree3, y_train.annual_salary)

# predict train

y_train['sal_pred_pm3'] = pm3.predict(X_train_degree3)

# evaluate: rmse
rmse_train = mean_squared_error(y_train.annual_salary, y_train.sal_pred_pm3) ** (1/2)

# predict validate
y_validate['sal_pred_pm3'] = pm3.predict(X_validate_degree3)

# evaluate: rmse
rmse_validate = mean_squared_error(y_validate.annual_salary, y_validate.sal_pred_pm3) ** (1/2)

print("RMSE for PolynomialRegression\nTraining/In-Sample: ", rmse_train, 
      "\nValidation/Out-of-Sample: ", rmse_validate)
# Out:
# RMSE for PolynomialRegression
# Training/In-Sample:  20946.689972325836
# Validation/Out-of-Sample:  20655.548766283388

# %%
# add model to metric df
metric_df = metric_df.append(
    {
    'model': 'PolyReg Model',
    'rmse_outofsample': rmse_validate,
    'r^2_outofsample': explained_variance_score(y_validate.annual_salary, y_validate.sal_pred_pm3)}, ignore_index=True)
metric_df
# Out:
#                   model  rmse_outofsample  r^2_outofsample
# 0       median_baseline      26448.162472         0.000000
# 1                OLS lm      22537.912413         0.214656
# 2     LassoLars alpha 1      22652.214468         0.206668
# 3   Tweedie GLM power 1      24964.304750         0.036377
# 4         PolyReg Model      22430.595042         0.222114
# 5         PolyReg Model      22430.595042         0.222114
# 6                  Test      22297.326172         0.243110
# 7                OLS lm      20911.988826         0.323853
# 8     LassoLars alpha 1      21104.629353         0.311349
# 9   Tweedie GLM power 1      23027.471708         0.180084
# 10        PolyReg Model      20290.719726         0.363431
# 11        PolyReg Model      20290.719726         0.363431
# 12                 Test      20108.904965         0.384399
# 13               OLS lm      21144.233716         0.308748
# 14    LassoLars alpha 1      21417.740768         0.290758
# 15  Tweedie GLM power 1      23393.862149         0.153787
# 16        PolyReg Model      20655.548766         0.340334
# 17        PolyReg Model      20655.548766         0.340334

# %%
# best model 2nd deg polynomial fit on test

# predict on test
y_test['sal_pred_pm'] = pm.predict(X_test_degree2)

# evaluate: rmse
rmse_test = mean_squared_error(y_test.annual_salary, y_test.sal_pred_pm) ** 0.5
print("RMSE for Model using PolynomialRegression\nOut-of-Sample Performance: ", rmse_test)
# Out:
# RMSE for Model using PolynomialRegression
# Out-of-Sample Performance:  20473.63879110279

# %%
metric_df = metric_df.append(
    {
    'model': 'Test',
    'rmse_outofsample': rmse_test,
    'r^2_outofsample': explained_variance_score(y_test.annual_salary, y_test.sal_pred_pm)}, ignore_index=True)

# %%
metric_df
# Out:
#                   model  rmse_outofsample  r^2_outofsample
# 0       median_baseline      26448.162472         0.000000
# 1                OLS lm      22537.912413         0.214656
# 2     LassoLars alpha 1      22652.214468         0.206668
# 3   Tweedie GLM power 1      24964.304750         0.036377
# 4         PolyReg Model      22430.595042         0.222114
# 5         PolyReg Model      22430.595042         0.222114
# 6                  Test      22297.326172         0.243110
# 7                OLS lm      20911.988826         0.323853
# 8     LassoLars alpha 1      21104.629353         0.311349
# 9   Tweedie GLM power 1      23027.471708         0.180084
# 10        PolyReg Model      20290.719726         0.363431
# 11        PolyReg Model      20290.719726         0.363431
# 12                 Test      20108.904965         0.384399
# 13               OLS lm      21144.233716         0.308748
# 14    LassoLars alpha 1      21417.740768         0.290758
# 15  Tweedie GLM power 1      23393.862149         0.153787
# 16        PolyReg Model      20655.548766         0.340334
# 17        PolyReg Model      20655.548766         0.340334
# 18                 Test      20473.638791         0.361867

# %%
# plot the residuals for the best performing model

plt.figure(figsize=(16,8))
plt.axhline(label="No Error")

plt.scatter(y_validate.annual_salary, y_validate.sal_pred_pm - y_validate.annual_salary, 
            alpha=.5, color="green", s=100, label="Model 2nd degree Polynomial")
plt.legend()
plt.xlabel("Actual Annual Salary")
plt.ylabel("Residual/Error: Predicted Salary - Actual")
plt.title("Do the size of errors change as the actual value changes?")

plt.show()

# %%
train.columns
# Out:
# Index(['agency_id', 'agency', 'lastname', 'firstname', 'title', 'race', 'sex',
#        'emptype', 'hire_date', 'hours_worked', 'monthly_salary',
#        'annual_salary', 'is_female', 'is_white', 'is_hispanic', 'is_black',
#        'is_BIPOC', 'race_encoded', 'tenure_months', 'tenure_years',
#        'is_elected', 'is_director', 'is_unclassified', 'is_parttime',
#        'tenure_years_bins', '0-5_years', '5-10_years', '10-20_years',
#        '>20_years'],
#       dtype='object')

# %%
features=['agency_id','0-5_years','tenure_months','tenure_years_bins','tenure_years','is_director']

# %%
# ols
# create the model object

lm = LinearRegression(fit_intercept=True)

# fit the model to our training data. We must specify the column in y_train, since we have converted it to a dataframe from a series! 

# fit the thing using only the features we selected
lm.fit(X_train[features], y_train.annual_salary)

# predict train

y_train['sal_pred_lm'] = lm.predict(X_train[features])

# evaluate: rmse
rmse_train = mean_squared_error(y_train.annual_salary, y_train.sal_pred_lm) ** (1/2)

# predict validate
y_validate['sal_pred_lm'] = lm.predict(X_validate[features])

# evaluate: rmse
rmse_validate = mean_squared_error(y_validate.annual_salary, y_validate.sal_pred_lm) ** (1/2)

print("RMSE for OLS using LinearRegression\nTraining/In-Sample: ", rmse_train, 
      "\nValidation/Out-of-Sample: ", rmse_validate)
# Out:
# RMSE for OLS using LinearRegression
# Training/In-Sample:  21663.783837973344
# Validation/Out-of-Sample:  21389.082518472744

# %%
# add model's performance to metric df
metric_df = metric_df.append(
    {
    'model': 'OLS lm',
    'rmse_outofsample': rmse_validate,
        'r^2_outofsample': explained_variance_score(y_validate.annual_salary, y_validate.sal_pred_lm)}, ignore_index=True)

# %%
# lasso lars

# create the model object
lars = LassoLars(alpha=1)

# fit the model to our training data using only selected features. We must specify the column in y_train, 
# since we have converted it to a dataframe from a series
lars.fit(X_train[features], y_train.annual_salary)

# predict train
y_train['sal_pred_lars'] = lars.predict(X_train[features])

# evaluate: rmse
rmse_train = mean_squared_error(y_train.annual_salary, y_train.sal_pred_lars) ** 0.5

# predict validate
y_validate['sal_pred_lars'] = lars.predict(X_validate[features])

# evaluate: rmse
rmse_validate = mean_squared_error(y_validate.annual_salary, y_validate.sal_pred_lars) ** 0.5

print("RMSE for Lasso + Lars\nTraining/In-Sample: ", rmse_train, 
      "\nValidation/Out-of-Sample: ", rmse_validate)
# Out:
# RMSE for Lasso + Lars
# Training/In-Sample:  21687.654403602864
# Validation/Out-of-Sample:  21423.104212220747

# %%
# add model to metric df
metric_df = metric_df.append(
    {
    'model': 'LassoLars alpha 1',
    'rmse_outofsample': rmse_validate,
    'r^2_outofsample': explained_variance_score(y_validate.annual_salary, y_validate.sal_pred_lars)}, ignore_index=True)

# %%
# glm
# create the model object
glm = TweedieRegressor(power=0, alpha=1)

# fit the model to our training data using only selected features. We must specify the column in y_train, 
# since we have converted it to a dataframe from a series

glm.fit(X_train[features], y_train.annual_salary)

# predict train
y_train['sal_pred_glm'] = glm.predict(X_train[features])

# evaluate: rmse
rmse_train = mean_squared_error(y_train.annual_salary, y_train.sal_pred_glm) ** 0.5


# predict validate
y_validate['sal_pred_glm'] = glm.predict(X_validate[features])

# evaluate: rmse
rmse_validate = mean_squared_error(y_validate.annual_salary, y_validate.sal_pred_glm) ** 0.5

print("RMSE for GLM using Tweedie, power=1 & alpha=0\nTraining/In-Sample: ", rmse_train, 
      "\nValidation/Out-of-Sample: ", rmse_validate)
# Out:
# RMSE for GLM using Tweedie, power=1 & alpha=0
# Training/In-Sample:  23725.31634022846
# Validation/Out-of-Sample:  23294.217579790897

# %%
# add model to metric df
metric_df = metric_df.append(
    {
    'model': 'Tweedie GLM power 1',
    'rmse_outofsample': rmse_validate,
    'r^2_outofsample': explained_variance_score(y_validate.annual_salary, y_validate.sal_pred_glm)}, ignore_index=True)

# %%
# 2nd deg polynomial
# make the polynomial features to get a new set of features
pf = PolynomialFeatures(degree=2)

# fit and transform X_train_scaled features
X_train_degree2 = pf.fit_transform(X_train[features])

# transform X_validate_scaled & X_test_scaled
X_validate_degree2 = pf.transform(X_validate[features])
X_test_degree2 = pf.transform(X_test[features])

# %%
#create the model object

pm = LinearRegression(normalize=True)

# fit the model to our training data. We must specify the column in y_train, 
# since we have converted it to a dataframe from a series! 

# fit the thing

pm.fit(X_train_degree2, y_train.annual_salary)

# predict train

y_train['sal_pred_pm'] = pm.predict(X_train_degree2)

# evaluate: rmse
rmse_train = mean_squared_error(y_train.annual_salary, y_train.sal_pred_pm) ** (1/2)

# predict validate
y_validate['sal_pred_pm'] = pm.predict(X_validate_degree2)

# evaluate: rmse
rmse_validate = mean_squared_error(y_validate.annual_salary, y_validate.sal_pred_pm) ** (1/2)

print("RMSE for PolynomialRegression\nTraining/In-Sample: ", rmse_train, 
      "\nValidation/Out-of-Sample: ", rmse_validate)
# Out:
# RMSE for PolynomialRegression
# Training/In-Sample:  21534.149543661748
# Validation/Out-of-Sample:  21244.1864944965

# %%
# add model to metric df
metric_df = metric_df.append(
    {
    'model': 'PolyReg Model',
    'rmse_outofsample': rmse_validate,
    'r^2_outofsample': explained_variance_score(y_validate.annual_salary, y_validate.sal_pred_pm)}, ignore_index=True)
metric_df
# Out:
#                   model  rmse_outofsample  r^2_outofsample
# 0       median_baseline      26448.162472         0.000000
# 1                OLS lm      22537.912413         0.214656
# 2     LassoLars alpha 1      22652.214468         0.206668
# 3   Tweedie GLM power 1      24964.304750         0.036377
# 4         PolyReg Model      22430.595042         0.222114
# 5         PolyReg Model      22430.595042         0.222114
# 6                  Test      22297.326172         0.243110
# 7                OLS lm      20911.988826         0.323853
# 8     LassoLars alpha 1      21104.629353         0.311349
# 9   Tweedie GLM power 1      23027.471708         0.180084
# 10        PolyReg Model      20290.719726         0.363431
# 11        PolyReg Model      20290.719726         0.363431
# 12                 Test      20108.904965         0.384399
# 13               OLS lm      21144.233716         0.308748
# 14    LassoLars alpha 1      21417.740768         0.290758
# 15  Tweedie GLM power 1      23393.862149         0.153787
# 16        PolyReg Model      20655.548766         0.340334
# 17        PolyReg Model      20655.548766         0.340334
# 18                 Test      20473.638791         0.361867
# 19               OLS lm      21389.082518         0.292657
# 20    LassoLars alpha 1      21423.104212         0.290408
# 21  Tweedie GLM power 1      23294.217580         0.160980
# 22        PolyReg Model      21244.186494         0.302204

# %%
# best model 2nd deg polynomial fit on test

# predict on test
y_test['sal_pred_pm'] = pm.predict(X_test_degree2)

# evaluate: rmse
rmse_test = mean_squared_error(y_test.annual_salary, y_test.sal_pred_pm) ** 0.5
print("RMSE for Model using PolynomialRegression\nOut-of-Sample Performance: ", rmse_test)
# Out:
# RMSE for Model using PolynomialRegression
# Out-of-Sample Performance:  21079.86535177184

# %%
metric_df = metric_df.append(
    {
    'model': 'Test',
    'rmse_outofsample': rmse_test,
    'r^2_outofsample': explained_variance_score(y_test.annual_salary, y_test.sal_pred_pm)}, ignore_index=True)

# %%
metric_df
# Out:
#                   model  rmse_outofsample  r^2_outofsample
# 0       median_baseline      26448.162472         0.000000
# 1                OLS lm      22537.912413         0.214656
# 2     LassoLars alpha 1      22652.214468         0.206668
# 3   Tweedie GLM power 1      24964.304750         0.036377
# 4         PolyReg Model      22430.595042         0.222114
# 5         PolyReg Model      22430.595042         0.222114
# 6                  Test      22297.326172         0.243110
# 7                OLS lm      20911.988826         0.323853
# 8     LassoLars alpha 1      21104.629353         0.311349
# 9   Tweedie GLM power 1      23027.471708         0.180084
# 10        PolyReg Model      20290.719726         0.363431
# 11        PolyReg Model      20290.719726         0.363431
# 12                 Test      20108.904965         0.384399
# 13               OLS lm      21144.233716         0.308748
# 14    LassoLars alpha 1      21417.740768         0.290758
# 15  Tweedie GLM power 1      23393.862149         0.153787
# 16        PolyReg Model      20655.548766         0.340334
# 17        PolyReg Model      20655.548766         0.340334
# 18                 Test      20473.638791         0.361867
# 19               OLS lm      21389.082518         0.292657
# 20    LassoLars alpha 1      21423.104212         0.290408
# 21  Tweedie GLM power 1      23294.217580         0.160980
# 22        PolyReg Model      21244.186494         0.302204
# 23                 Test      21079.865352         0.323511
