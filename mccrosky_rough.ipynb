# %%
import math
import warnings
warnings.filterwarnings("ignore")

import pandas as pd
import numpy as np
import seaborn as sns  
import matplotlib.pyplot as plt
from scipy import stats
from datetime import datetime

from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import explained_variance_score
from sklearn.metrics import mean_squared_error
from sklearn.linear_model import LinearRegression, LassoLars, TweedieRegressor
from sklearn.preprocessing import PolynomialFeatures
import sklearn.preprocessing
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score, mean_squared_error
from sklearn.feature_selection import SelectKBest, f_regression, RFE

# %% [markdown]
# ## Acquiring Our Dataframe

# %%
df = pd.read_csv('texas.csv', index_col=0) ## reading our csv into a pandas dataframe

df.head() ## previewing our data
# Out:
#                                                   NAME  \
# AGY
# 101  SENATE                                        ...
# 104  LEGISLATIVE BUDGET BOARD                      ...
# 101  SENATE                                        ...
# 104  LEGISLATIVE BUDGET BOARD                      ...
# 101  SENATE                                        ...
#
#                            LASTNAME                       FIRSTNAME MI  \
# AGY
# 101  GILLIAM                         STACEY                          L
# 104  GILLIAM                         STACEY                          L
# 101  NELSON                          DAVID
# 104  NELSON                          DAVID
# 101  ROCHA                           MARIE                           S
#
#      JOBCLASS                                           JC TITLE  \
# AGY
# 101  7101      LEG. OFFICIAL/ADMINISTRATOR                   ...
# 104  C160      COMMITTEE DIRECTOR                            ...
# 101  7101      LEG. OFFICIAL/ADMINISTRATOR                   ...
# 104  P080      SENIOR BUDGET ADVISOR                         ...
# 101  7103      LEG. SERVICE/MAINTENANCE                      ...
#
#                 RACE              SEX  \
# AGY
# 101  WHITE            FEMALE
# 104  WHITE            FEMALE
# 101  WHITE            MALE
# 104  WHITE            MALE
# 101  HISPANIC         FEMALE
#
#                                       EMPTYPE    HIREDT  RATE  HRSWKD  \
# AGY
# 101  URP - UNCLASSIFIED REGULAR PART-TIME      07/01/13   0.0    20.0
# 104  URP - UNCLASSIFIED REGULAR PART-TIME      11/01/17   0.0    20.0
# 101  URP - UNCLASSIFIED REGULAR PART-TIME      12/01/98   0.0    20.0
# 104  URP - UNCLASSIFIED REGULAR PART-TIME      11/01/17   0.0    20.0
# 101  URF - UNCLASSIFIED REGULAR FULL-TIME      05/01/03   0.0    41.0
#
#      MONTHLY    ANNUAL  STATENUM duplicated multiple_full_time_jobs  \
# AGY
# 101   8100.0   97200.0    339371       True                     NaN
# 104   7000.0   84000.0    339371       True                     NaN
# 101   9500.0  114000.0    193187       True                     NaN
# 104   8000.0   96000.0    193187       True                     NaN
# 101   3365.4   40384.8    152257       True                     NaN
#
#     combined_multiple_jobs  summed_annual_salary hide_from_search
# AGY
# 101                    NaN              181200.0              NaN
# 104                    NaN                   NaN             True
# 101                    NaN              210000.0              NaN
# 104                    NaN                   NaN             True
# 101                   True                   NaN              NaN

# %%
df.shape ## checking the shape of our dataframe
# Out:
# (144738, 20)

# %%
## checking our column data types

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 144738 entries, 101 to 809
# Data columns (total 20 columns):
#  #   Column                   Non-Null Count   Dtype
# ---  ------                   --------------   -----
#  0   NAME                     144738 non-null  object
#  1   LASTNAME                 144738 non-null  object
#  2   FIRSTNAME                144738 non-null  object
#  3   MI                       144738 non-null  object
#  4   JOBCLASS                 144738 non-null  object
#  5   JC TITLE                 144738 non-null  object
#  6   RACE                     144738 non-null  object
#  7   SEX                      144738 non-null  object
#  8   EMPTYPE                  144738 non-null  object
#  9   HIREDT                   144738 non-null  object
#  10  RATE                     144738 non-null  float64
#  11  HRSWKD                   144738 non-null  float64
#  12  MONTHLY                  144738 non-null  float64
#  13  ANNUAL                   144738 non-null  float64
#  14  STATENUM                 144738 non-null  int64
#  15  duplicated               76 non-null      object
#  16  multiple_full_time_jobs  18 non-null      object
#  17  combined_multiple_jobs   37 non-null      object
#  18  summed_annual_salary     11 non-null      float64
#  19  hide_from_search         11 non-null      object
# dtypes: float64(5), int64(1), object(14)
# memory usage: 23.2+ MB

# %% [markdown]
# ## Preparing Our Dataframe

# %% [markdown]
# ### Prepare: Clean & Prep

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
## first let's rename all the columns to lowercase for easeier workflow

df.rename(str.lower, axis='columns', inplace=True)

# %%
## now let's remove any potential leading whitesapce

df.columns = df.columns.str.strip()

# %%
df.head() ## previewing our changes
# Out:
#                                                   name  \
# AGY
# 101  SENATE                                        ...
# 104  LEGISLATIVE BUDGET BOARD                      ...
# 101  SENATE                                        ...
# 104  LEGISLATIVE BUDGET BOARD                      ...
# 101  SENATE                                        ...
#
#                            lastname                       firstname mi  \
# AGY
# 101  GILLIAM                         STACEY                          L
# 104  GILLIAM                         STACEY                          L
# 101  NELSON                          DAVID
# 104  NELSON                          DAVID
# 101  ROCHA                           MARIE                           S
#
#      jobclass                                           jc title  \
# AGY
# 101  7101      LEG. OFFICIAL/ADMINISTRATOR                   ...
# 104  C160      COMMITTEE DIRECTOR                            ...
# 101  7101      LEG. OFFICIAL/ADMINISTRATOR                   ...
# 104  P080      SENIOR BUDGET ADVISOR                         ...
# 101  7103      LEG. SERVICE/MAINTENANCE                      ...
#
#                 race              sex  \
# AGY
# 101  WHITE            FEMALE
# 104  WHITE            FEMALE
# 101  WHITE            MALE
# 104  WHITE            MALE
# 101  HISPANIC         FEMALE
#
#                                       emptype    hiredt  rate  hrswkd  \
# AGY
# 101  URP - UNCLASSIFIED REGULAR PART-TIME      07/01/13   0.0    20.0
# 104  URP - UNCLASSIFIED REGULAR PART-TIME      11/01/17   0.0    20.0
# 101  URP - UNCLASSIFIED REGULAR PART-TIME      12/01/98   0.0    20.0
# 104  URP - UNCLASSIFIED REGULAR PART-TIME      11/01/17   0.0    20.0
# 101  URF - UNCLASSIFIED REGULAR FULL-TIME      05/01/03   0.0    41.0
#
#      monthly    annual  statenum duplicated multiple_full_time_jobs  \
# AGY
# 101   8100.0   97200.0    339371       True                     NaN
# 104   7000.0   84000.0    339371       True                     NaN
# 101   9500.0  114000.0    193187       True                     NaN
# 104   8000.0   96000.0    193187       True                     NaN
# 101   3365.4   40384.8    152257       True                     NaN
#
#     combined_multiple_jobs  summed_annual_salary hide_from_search
# AGY
# 101                    NaN              181200.0              NaN
# 104                    NaN                   NaN             True
# 101                    NaN              210000.0              NaN
# 104                    NaN                   NaN             True
# 101                   True                   NaN              NaN

# %%
df.columns ## previewing our columns
# Out:
# Index(['name', 'lastname', 'firstname', 'mi', 'jobclass', 'jc title', 'race',
#        'sex', 'emptype', 'hiredt', 'rate', 'hrswkd', 'monthly', 'annual',
#        'statenum', 'duplicated', 'multiple_full_time_jobs',
#        'combined_multiple_jobs', 'summed_annual_salary', 'hide_from_search'],
#       dtype='object')

# %%
## Let's drop unneccasry columns that won't be any help with predicting our
## target variable because they are either incomplete or unsignificant information

df = df.drop(columns = ['jobclass','mi', 'rate', 'statenum', 'duplicated', 'multiple_full_time_jobs',
       'combined_multiple_jobs', 'summed_annual_salary', 'hide_from_search'])

# %%
df.head() ## previewing our changes
# Out:
#                                                   name  \
# AGY
# 101  SENATE                                        ...
# 104  LEGISLATIVE BUDGET BOARD                      ...
# 101  SENATE                                        ...
# 104  LEGISLATIVE BUDGET BOARD                      ...
# 101  SENATE                                        ...
#
#                            lastname                       firstname  \
# AGY
# 101  GILLIAM                         STACEY
# 104  GILLIAM                         STACEY
# 101  NELSON                          DAVID
# 104  NELSON                          DAVID
# 101  ROCHA                           MARIE
#
#                                               jc title             race  \
# AGY
# 101  LEG. OFFICIAL/ADMINISTRATOR                   ...  WHITE
# 104  COMMITTEE DIRECTOR                            ...  WHITE
# 101  LEG. OFFICIAL/ADMINISTRATOR                   ...  WHITE
# 104  SENIOR BUDGET ADVISOR                         ...  WHITE
# 101  LEG. SERVICE/MAINTENANCE                      ...  HISPANIC
#
#                  sex                                   emptype    hiredt  \
# AGY
# 101  FEMALE           URP - UNCLASSIFIED REGULAR PART-TIME      07/01/13
# 104  FEMALE           URP - UNCLASSIFIED REGULAR PART-TIME      11/01/17
# 101  MALE             URP - UNCLASSIFIED REGULAR PART-TIME      12/01/98
# 104  MALE             URP - UNCLASSIFIED REGULAR PART-TIME      11/01/17
# 101  FEMALE           URF - UNCLASSIFIED REGULAR FULL-TIME      05/01/03
#
#      hrswkd  monthly    annual
# AGY
# 101    20.0   8100.0   97200.0
# 104    20.0   7000.0   84000.0
# 101    20.0   9500.0  114000.0
# 104    20.0   8000.0   96000.0
# 101    41.0   3365.4   40384.8

# %%
## renaming columns for ease of workflow

df = df.rename(columns = {'jc title': 'title', 
                          'hiredt': 'hire_date', 
                          'hrswkd': 'hours_worked',
                          'name': 'agency',
                          'agy': 'agency_id',
                          'monthly': 'monthly_salary',
                          'annual': 'annual_salary'})

df.head() ## previewing our changes
# Out:
#                                                 agency  \
# AGY
# 101  SENATE                                        ...
# 104  LEGISLATIVE BUDGET BOARD                      ...
# 101  SENATE                                        ...
# 104  LEGISLATIVE BUDGET BOARD                      ...
# 101  SENATE                                        ...
#
#                            lastname                       firstname  \
# AGY
# 101  GILLIAM                         STACEY
# 104  GILLIAM                         STACEY
# 101  NELSON                          DAVID
# 104  NELSON                          DAVID
# 101  ROCHA                           MARIE
#
#                                                  title             race  \
# AGY
# 101  LEG. OFFICIAL/ADMINISTRATOR                   ...  WHITE
# 104  COMMITTEE DIRECTOR                            ...  WHITE
# 101  LEG. OFFICIAL/ADMINISTRATOR                   ...  WHITE
# 104  SENIOR BUDGET ADVISOR                         ...  WHITE
# 101  LEG. SERVICE/MAINTENANCE                      ...  HISPANIC
#
#                  sex                                   emptype hire_date  \
# AGY
# 101  FEMALE           URP - UNCLASSIFIED REGULAR PART-TIME      07/01/13
# 104  FEMALE           URP - UNCLASSIFIED REGULAR PART-TIME      11/01/17
# 101  MALE             URP - UNCLASSIFIED REGULAR PART-TIME      12/01/98
# 104  MALE             URP - UNCLASSIFIED REGULAR PART-TIME      11/01/17
# 101  FEMALE           URF - UNCLASSIFIED REGULAR FULL-TIME      05/01/03
#
#      hours_worked  monthly_salary  annual_salary
# AGY
# 101          20.0          8100.0        97200.0
# 104          20.0          7000.0        84000.0
# 101          20.0          9500.0       114000.0
# 104          20.0          8000.0        96000.0
# 101          41.0          3365.4        40384.8

# %%
## changing hire date to date time format

df.hire_date = pd.to_datetime(df.hire_date)

df.info() ## previewing data type changes
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 144738 entries, 101 to 809
# Data columns (total 11 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   agency          144738 non-null  object
#  1   lastname        144738 non-null  object
#  2   firstname       144738 non-null  object
#  3   title           144738 non-null  object
#  4   race            144738 non-null  object
#  5   sex             144738 non-null  object
#  6   emptype         144738 non-null  object
#  7   hire_date       144738 non-null  datetime64[ns]
#  8   hours_worked    144738 non-null  float64
#  9   monthly_salary  144738 non-null  float64
#  10  annual_salary   144738 non-null  float64
# dtypes: datetime64[ns](1), float64(3), object(7)
# memory usage: 13.3+ MB

# %%
df.isnull().sum() ## checking for nulls

## BEAUTIFUL RESULTS :D
# Out:
# agency            0
# lastname          0
# firstname         0
# title             0
# race              0
# sex               0
# emptype           0
# hire_date         0
# hours_worked      0
# monthly_salary    0
# annual_salary     0
# dtype: int64

# %%
df.duplicated().sum() ## checking for duplicate rows.
# Out:
# 5

# %%
## dropping the duplciates rows
df = df.drop_duplicates()

# %%
df.duplicated().sum() ## rechecking for duplicate rows.
# Out:
# 0

# %%
## checking our dataframe shape after cleaning
df.shape
# Out:
# (144733, 11)

# %% [markdown]
# ### Prepare Takeaways

# %% [markdown]
# * Many of the columns were capitalized and were changed to all lowercase characters. Some of the column names had spaces that were also taken removed.
# * After dropping unneccessary columns we checked for nulls and found zero, the data was already complete.
# * We now have a clean workable dataframe and can move on to feature engineering

# %% [markdown]
# ### Prepare: Create Features

# %%
## previewing our dataframe
df.head(3)
# Out:
#                                                 agency  \
# AGY
# 101  SENATE                                        ...
# 104  LEGISLATIVE BUDGET BOARD                      ...
# 101  SENATE                                        ...
#
#                            lastname                       firstname  \
# AGY
# 101  GILLIAM                         STACEY
# 104  GILLIAM                         STACEY
# 101  NELSON                          DAVID
#
#                                                  title             race  \
# AGY
# 101  LEG. OFFICIAL/ADMINISTRATOR                   ...  WHITE
# 104  COMMITTEE DIRECTOR                            ...  WHITE
# 101  LEG. OFFICIAL/ADMINISTRATOR                   ...  WHITE
#
#                  sex                                   emptype  hire_date  \
# AGY
# 101  FEMALE           URP - UNCLASSIFIED REGULAR PART-TIME     2013-07-01
# 104  FEMALE           URP - UNCLASSIFIED REGULAR PART-TIME     2017-11-01
# 101  MALE             URP - UNCLASSIFIED REGULAR PART-TIME     1998-12-01
#
#      hours_worked  monthly_salary  annual_salary
# AGY
# 101          20.0          8100.0        97200.0
# 104          20.0          7000.0        84000.0
# 101          20.0          9500.0       114000.0

# %%
## one hot encoding column for gender

df['is_female'] = np.where(df.sex == 'FEMALE', 1, 0)

# %%
df.is_female.value_counts()
# Out:
# 0    144733
# Name: is_female, dtype: int64

# %%
## looking at the different races in the dataframe
df.race.value_counts()
# Out:
# WHITE              64650
# HISPANIC           39554
# BLACK              33963
# ASIAN               4419
# OTHER               1453
# AM INDIAN            694
# Name: race, dtype: int64

# %%
## one hot encoding the top three races in the dataframe

df['is_white'] = np.where(df.race == 'WHITE', 1, 0)
df['is_hispanic'] = np.where(df.race == 'HISPANIC', 1, 0)
df['is_black'] = np.where(df.race == 'BLACK', 1, 0)

# %%
df.is_hispanic.value_counts()
# Out:
# 0    144733
# Name: is_hispanic, dtype: int64

# %%
df.head() ## previewing changes
# Out:
#                                                 agency  \
# AGY
# 101  SENATE                                        ...
# 104  LEGISLATIVE BUDGET BOARD                      ...
# 101  SENATE                                        ...
# 104  LEGISLATIVE BUDGET BOARD                      ...
# 101  SENATE                                        ...
#
#                            lastname                       firstname  \
# AGY
# 101  GILLIAM                         STACEY
# 104  GILLIAM                         STACEY
# 101  NELSON                          DAVID
# 104  NELSON                          DAVID
# 101  ROCHA                           MARIE
#
#                                                  title             race  \
# AGY
# 101  LEG. OFFICIAL/ADMINISTRATOR                   ...  WHITE
# 104  COMMITTEE DIRECTOR                            ...  WHITE
# 101  LEG. OFFICIAL/ADMINISTRATOR                   ...  WHITE
# 104  SENIOR BUDGET ADVISOR                         ...  WHITE
# 101  LEG. SERVICE/MAINTENANCE                      ...  HISPANIC
#
#                  sex                                   emptype  hire_date  \
# AGY
# 101  FEMALE           URP - UNCLASSIFIED REGULAR PART-TIME     2013-07-01
# 104  FEMALE           URP - UNCLASSIFIED REGULAR PART-TIME     2017-11-01
# 101  MALE             URP - UNCLASSIFIED REGULAR PART-TIME     1998-12-01
# 104  MALE             URP - UNCLASSIFIED REGULAR PART-TIME     2017-11-01
# 101  FEMALE           URF - UNCLASSIFIED REGULAR FULL-TIME     2003-05-01
#
#      hours_worked  monthly_salary  annual_salary  is_female  is_white  \
# AGY
# 101          20.0          8100.0        97200.0          0         0
# 104          20.0          7000.0        84000.0          0         0
# 101          20.0          9500.0       114000.0          0         0
# 104          20.0          8000.0        96000.0          0         0
# 101          41.0          3365.4        40384.8          0         0
#
#      is_hispanic  is_black
# AGY
# 101            0         0
# 104            0         0
# 101            0         0
# 104            0         0
# 101            0         0

# %%
label_encoder = LabelEncoder() ## creating my label encoder

## creating a race column that is incoded for machine readable formate
df['race_encoded'] = label_encoder.fit_transform(df['race'])

# %%
df.race_encoded.value_counts() ## previewing changes
# Out:
# 5    64650
# 3    39554
# 2    33963
# 1     4419
# 4     1453
# 0      694
# Name: race_encoded, dtype: int64

# %%
df.race.value_counts() ## comparing changes
# Out:
# WHITE              64650
# HISPANIC           39554
# BLACK              33963
# ASIAN               4419
# OTHER               1453
# AM INDIAN            694
# Name: race, dtype: int64

# %%
df.head() ## previewing changes
# Out:
#                                                 agency  \
# AGY
# 101  SENATE                                        ...
# 104  LEGISLATIVE BUDGET BOARD                      ...
# 101  SENATE                                        ...
# 104  LEGISLATIVE BUDGET BOARD                      ...
# 101  SENATE                                        ...
#
#                            lastname                       firstname  \
# AGY
# 101  GILLIAM                         STACEY
# 104  GILLIAM                         STACEY
# 101  NELSON                          DAVID
# 104  NELSON                          DAVID
# 101  ROCHA                           MARIE
#
#                                                  title             race  \
# AGY
# 101  LEG. OFFICIAL/ADMINISTRATOR                   ...  WHITE
# 104  COMMITTEE DIRECTOR                            ...  WHITE
# 101  LEG. OFFICIAL/ADMINISTRATOR                   ...  WHITE
# 104  SENIOR BUDGET ADVISOR                         ...  WHITE
# 101  LEG. SERVICE/MAINTENANCE                      ...  HISPANIC
#
#                  sex                                   emptype  hire_date  \
# AGY
# 101  FEMALE           URP - UNCLASSIFIED REGULAR PART-TIME     2013-07-01
# 104  FEMALE           URP - UNCLASSIFIED REGULAR PART-TIME     2017-11-01
# 101  MALE             URP - UNCLASSIFIED REGULAR PART-TIME     1998-12-01
# 104  MALE             URP - UNCLASSIFIED REGULAR PART-TIME     2017-11-01
# 101  FEMALE           URF - UNCLASSIFIED REGULAR FULL-TIME     2003-05-01
#
#      hours_worked  monthly_salary  annual_salary  is_female  is_white  \
# AGY
# 101          20.0          8100.0        97200.0          0         0
# 104          20.0          7000.0        84000.0          0         0
# 101          20.0          9500.0       114000.0          0         0
# 104          20.0          8000.0        96000.0          0         0
# 101          41.0          3365.4        40384.8          0         0
#
#      is_hispanic  is_black  race_encoded
# AGY
# 101            0         0             5
# 104            0         0             5
# 101            0         0             5
# 104            0         0             5
# 101            0         0             3

# %%
## creating a tenure in months column by subrtracting the hire date from the last updated 
## date of the dataframe (7/1/21) and dividing it by a time delta 

df['tenure_months'] = np.round((pd.to_datetime('2021-07-01') - df['hire_date'])/np.timedelta64(1,'M'))

## casting tenure in months as an ints
df['tenure_months'] = df['tenure_months'].astype(int)

# %%
df['tenure_years'] = np.round(df['tenure_months'] / 12, 1)

# %%
df.head() ## previewing changes
# Out:
#                                                 agency  \
# AGY
# 101  SENATE                                        ...
# 104  LEGISLATIVE BUDGET BOARD                      ...
# 101  SENATE                                        ...
# 104  LEGISLATIVE BUDGET BOARD                      ...
# 101  SENATE                                        ...
#
#                            lastname                       firstname  \
# AGY
# 101  GILLIAM                         STACEY
# 104  GILLIAM                         STACEY
# 101  NELSON                          DAVID
# 104  NELSON                          DAVID
# 101  ROCHA                           MARIE
#
#                                                  title             race  \
# AGY
# 101  LEG. OFFICIAL/ADMINISTRATOR                   ...  WHITE
# 104  COMMITTEE DIRECTOR                            ...  WHITE
# 101  LEG. OFFICIAL/ADMINISTRATOR                   ...  WHITE
# 104  SENIOR BUDGET ADVISOR                         ...  WHITE
# 101  LEG. SERVICE/MAINTENANCE                      ...  HISPANIC
#
#                  sex                                   emptype  hire_date  \
# AGY
# 101  FEMALE           URP - UNCLASSIFIED REGULAR PART-TIME     2013-07-01
# 104  FEMALE           URP - UNCLASSIFIED REGULAR PART-TIME     2017-11-01
# 101  MALE             URP - UNCLASSIFIED REGULAR PART-TIME     1998-12-01
# 104  MALE             URP - UNCLASSIFIED REGULAR PART-TIME     2017-11-01
# 101  FEMALE           URF - UNCLASSIFIED REGULAR FULL-TIME     2003-05-01
#
#      hours_worked  monthly_salary  annual_salary  is_female  is_white  \
# AGY
# 101          20.0          8100.0        97200.0          0         0
# 104          20.0          7000.0        84000.0          0         0
# 101          20.0          9500.0       114000.0          0         0
# 104          20.0          8000.0        96000.0          0         0
# 101          41.0          3365.4        40384.8          0         0
#
#      is_hispanic  is_black  race_encoded  tenure_months  tenure_years
# AGY
# 101            0         0             5             96           8.0
# 104            0         0             5             44           3.7
# 101            0         0             5            271          22.6
# 104            0         0             5             44           3.7
# 101            0         0             3            218          18.2

# %%
df['tenure_months'].max(), df['tenure_months'].min()
# Out:
# (597, -576)

# %%
df[df.tenure_months < 0]
# Out:
#                                                 agency  \
# AGY
# 102  HOUSE OF REPRESENTATIVES                      ...
# 696  TEXAS DEPARTMENT OF CRIMINAL JUSTICE          ...
# 592  SOIL AND WATER CONSERVATION BOARD             ...
#
#                            lastname                       firstname  \
# AGY
# 102  CRADDICK                        TOM
# 696  JUDD                            ARTHUR
# 592  BRANDENBERGER                   DONALD
#
#                                                  title             race  \
# AGY
# 102  ELECTED OFFICIAL                              ...  WHITE
# 696  AGRICULTURE SPEC V                            ...  WHITE
# 592  PROGRAM SPECIALIST VII                        ...  WHITE
#
#                  sex                                   emptype  hire_date  \
# AGY
# 102  MALE             URF - UNCLASSIFIED REGULAR FULL-TIME     2069-01-14
# 696  MALE             CRF - CLASSIFIED REGULAR FULL-TIME       2069-07-14
# 592  MALE             CRF - CLASSIFIED REGULAR FULL-TIME       2068-12-01
#
#      hours_worked  monthly_salary  annual_salary  is_female  is_white  \
# AGY
# 102          40.0          600.00        7200.00          0         0
# 696          40.0         4033.74       48404.88          0         0
# 592          40.0         7658.41       91900.92          0         0
#
#      is_hispanic  is_black  race_encoded  tenure_months  tenure_years
# AGY
# 102            0         0             5           -570         -47.5
# 696            0         0             5           -576         -48.0
# 592            0         0             5           -569         -47.4

# %%
## getting rid of clerical errors

df = df.drop(index=[794, 118710, 144495])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-35-e9c6951f823d> in <module>
#       1 ## getting rid of clerical errors
#       2
# ----> 3 df = df.drop(index=[794, 118710, 144495])
#
# /usr/local/anaconda3/lib/python3.8/site-packages/pandas/core/frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4161                 weight  1.0     0.8
#    4162         """
# -> 4163         return super().drop(
#    4164             labels=labels,
#    4165             axis=axis,
#
# /usr/local/anaconda3/lib/python3.8/site-packages/pandas/core/generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3885         for axis, labels in axes.items():
#    3886             if labels is not None:
# -> 3887                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    3888
#    3889         if inplace:
#
# /usr/local/anaconda3/lib/python3.8/site-packages/pandas/core/generic.py in _drop_axis(self, labels, axis, level, errors)
#    3938                 labels_missing = (axis.get_indexer_for(labels) == -1).any()
#    3939                 if errors == "raise" and labels_missing:
# -> 3940                     raise KeyError(f"{labels} not found in axis")
#    3941
#    3942             slicer = [slice(None)] * self.ndim
#
# KeyError: '[794 118710 144495] not found in axis'

# %%
df[df.tenure_months == 0]

# %%
df['tenure_months'].max(), df['tenure_months'].min()

# %%
df.head()

# %%
df.is_white.value_counts()
